# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


url = "https://www.daraz.lk/products/orient-mysoor-dhal-500g-i131664382-s1049417159.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253A%253Bnid%253A131664382%253Bsrc%253ALazadaMainSrp%253Brn%253Ad6a4467d55ac2dcdd96af14e1fccaac3%253Bregion%253Alk%253Bsku%253A131664382_LK%253Bprice%253A178%253Bclient%253Adesktop%253Bsupplier_id%253A1000000%253Bsession_id%253A%253Bbiz_source%253Ah5_pdp%253Bslot%253A0%253Butlog_bucket_id%253A470687%253Basc_category_id%253A10002458%253Bitem_id%253A131664382%253Bsku_id%253A1049417159%253Bshop_id%253A134061%253BtemplateInfo%253A&configId=choice_LK_promotion&freeshipping=0&fs_ab=1&fuse_fs=&lang=en&location=Western&price=178&priceCompare=skuId%3A1049417159%3Bsource%3Alazada-search-voucher%3Bsn%3Ad6a4467d55ac2dcdd96af14e1fccaac3%3BoriginPrice%3A17800%3BdisplayPrice%3A17800%3BsinglePromotionId%3A-1%3BsingleToolCode%3AmockedSalePrice%3BvoucherPricePlugin%3A0%3Btimestamp%3A1771996131960&ratingscore=4.865470852017937&request_id=d6a4467d55ac2dcdd96af14e1fccaac3&review=669&sale=10383&search=1&source=search&spm=a211g0.searchlist.list.0&stock=1&upItemIds=131664382"


options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(url)

time.sleep(8)


driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(5)


list_rows = []

reviews = driver.find_elements(By.CSS_SELECTOR, "div.content")

for review in reviews:
    text = review.text.strip()
    if text:
        print(text)
        list_rows.append(text)

print("Total reviews:", len(list_rows))

df = pd.DataFrame(list_rows, columns=["Review"])
df.to_excel("daraz_reviews.xlsx", index=False)

driver.quit()
# Out:
# 4.9/5
# 668 Ratings
# 623
# 25
# 6
# 3
# 11
# daraz supiri sellerth supiri😁
# Received safely in a very good condition. Satisfied with the product and service. Thank you Daraz and seller....
# ඔඩර් එක දලා දවසක් ඇතුලට පාසල් එක අතටම හම්බුනා එක පැකට් එකක්වත් ඩෑමේජ් වෙලා නෑ හොදටම තියෙනවා... ගොඩක් Thanks Daraz...❤️
# its good.. well packaged and super fast delivery..will order again
# A great product at a great price.. It was packaged very well.
# Total reviews: 6
